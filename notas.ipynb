# %% [markdown]
# # Consultar lo dataset

# %%
import pandas as pd

# %%
dfNotas = pd.read_csv('data/notas.csv')
dfUsuarios = pd.read_csv('data/usuarios.csv')

print(dfNotas.info())
print(dfUsuarios.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             100 non-null    int64
#  1   estudiante_id  100 non-null    object
#  2   materia        99 non-null     object
#  3   nota           100 non-null    object
#  4   fecha          11 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 4.7+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      120 non-null    object
#  1   nombre  118 non-null    object
#  2   rol     120 non-null    object
#  3   correo  119 non-null    object
# dtypes: object(4)
# memory usage: 3.9+ KB
# None

# %%
dfNotas.head(20)
# Out:
#     id estudiante_id    materia        nota       fecha
# 0    1   matemátic@s          3           5  2023/05/10
# 1    2      Lengu@@a   aprobado  10-05-2023         NaN
# 2    3      Hist0ria  excelente       fecha         NaN
# 3    4      ci3ncias        NaN  2023-03-15         NaN
# 4    5        Ingles        2.8  2023/11/20         NaN
# 5    6        ingles          4           5  15-07-2023
# 6    7       LenguuA       malo  2023/09/12         NaN
# 7    8   matematicas         -1  2023/02/18         NaN
# 8    9      ciencias        6.0  2023-04-25         NaN
# 9   10      historia             2023/08/05         NaN
# 10  11        lengua          3           2       fecha
# 11  12   Matematicas             2023/01/30         NaN
# 12  13      Historia          5           0  2023-06-12
# 13  14        ingles  excelente  20-11-2023         NaN
# 14  15      Ciencias          2           7  2023/12/01
# 15  16        lengua          4  2023/09/10         NaN
# ...

# %%
dfUsuarios.head(20)
# Out:
#    id               nombre         rol                     correo
# 0   1      Jeffrey Miller   Estudiante         aaron12@hansen.com
# 1   2        Manuel Davis   Estudiante     destinybrock@gmail.com
# 2   3   Austin Livingston   Estudiante        jtorres@hotmail.com
# 3   4       Michael Lopez   Estudiante          omills@taylor.com
# 4   5       Matthew Marks   Estudiante    bcobb@willis-taylor.com
# 5   6        Joshua Moore   Estudiante   sarahschmidt@hotmail.com
# 6   7         Sherry Holt   Estudiante  veronicagonzalez@mata.com
# 7   8       James Francis   Estudiante         sharon97@yahoo.com
# 8   9        Melissa Khan   Estudiante      jameswilson@gomez.com
# 9  10        Steven Scott   Estudiante     xmaldonado@hotmail.com

# %%
# Corregimos el tipo de dato de 'Stock' a entero
dfNotas['nota'] = dfNotas['nota'].astype(bool)

# %%
promedio_general = dfNotas['nota'].mean()
dfNotas['nota'].fillna(promedio_general, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 promedio_general = dfNotas['nota'].mean()
#       2 dfNotas['nota'].fillna(promedio_general, inplace=True)
#
# File c:\Users\USER\Desktop\ProyectoAnalisisDeDatos\.venv\Lib\site-packages\pandas\core\series.py:6560, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6552 @doc(make_doc("mean", ndim=1))
#    6553 def mean(
#    6554     self,
#    (...)   6558     **kwargs,
#    6559 ):
# -> 6560     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\USER\Desktop\ProyectoAnalisisDeDatos\.venv\Lib\site-packages\pandas\core\generic.py:12439, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12432 def mean(
#   12433     self,
#   12434     axis: Axis | None = 0,
#    (...)  12437     **kwargs,
#   12438 ) -> Series | float:
# ...
